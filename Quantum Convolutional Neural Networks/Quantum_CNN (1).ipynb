# %% [markdown]
# ## Quantum Convolutional Neural Networks
#
# Here, we will implement a Quantum Convolutional Neural Network , a quantum machine learning model, introduced by [Henderson et al.](https://arxiv.org/abs/1904.04767)

# %% [markdown]
# #### Classical Convolution
#
# The convolutional neural network (CNN) is a standard model in classical machine learning which is particularly suitable for processing images. The model is based on the idea of a convolution layer where, instead of processing the full input data with a global function, a local convolution is applied.
#
# If the input is an image, small local regions are sequentially processed with the same kernel. The results obtained for each region are usually associated to different channels of a single output pixel. The union of all the output pixels produces a new image-like object, which can be further processed by additional layers

# %% [markdown]
# ### Quantum Convolution
#
# Same idea can be used in quantum variational circuits.
#
#
#
# 1.   A small region of the input image $2 \times 2$ square (in our examples) is embedded into a quantum circuit. We achieve this with the help of parameterized rotations applied to the qubits intialized in the ground state.
# 2.   A quantum computation, associated to a unitary $U$, is performed on the system. The unitary could be generated by a variational quantum circuit, or by a random circuit.
#
# 3. The quantum system is finally measured, obtaining a list of classical expectation values. The measurement results could also be classicaly post-processed.
#
# 4. Analogously to a classical convolutional layer, each expectation value is mapped to a different channel of a single output pixel
#
# 5. Iterating the same procedure over different regions, we can scan the entire image, producing an output object which will be structured as multi-channel image.
#
# 6. The quantum convolution can be followed by further quantum layers or by classical layers.

# %% [markdown]
# ## Importing basic libraries

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers

import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting the main hyper-parameters

# %%
n_epochs = 40     # number of epochs to run
n_layers = 10     # number of random layers
n_train = 500      # size of training dataset
n_test = 300       # size of test dataset



SAVE_PATH = 'qcnn/'   # where to save
PREPROCESS = True    # if false, skip quantum processing and load data from saved path

np.random.seed(135)
tf.random.set_seed(135)

# %% [markdown]
# ### Load the dataset
# We will work with the MNIST dataset, which is already available in tensorflow.

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# %% [markdown]
# We will only be working with a small subset of the entire problem

# %%
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]

# for the test data
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# %% [markdown]
# ## Normalizing the data

# %%
train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# #### Adding an extra dimension for the convolutional channels

# %%
train_images = np.array(train_images[..., tf.newaxis], requires_grad = False)

test_images = np.array(test_images[..., tf.newaxis], requires_grad = False)

# %% [markdown]
# ### Quantum Circuit as a convolution kernel

# %% [markdown]
# We follow the scheme  described below. We initialize the Pennylane ```default.qubit``` device, simulating a system of 4 Qubits.
# The associated ```qnode```  represents the quantum circuit consisiting of:
#
#
#
# 1.   an embedding layer of local $R_y$ rotations (with angles scaled by a factor of $\pi$)
# 2.   a random circuit of ```n_layers```
# 3. a final measurement in the computational basis, estimating $4$ expectation values.

# %%
dev = qml.device('default.qubit', wires=4)

# now the random circuit

rand_params = np.random.uniform(high=2*np.pi, size = (n_layers,4))

@qml.qnode(dev)

def circuit(phi):
  # encoding of 4 classical input
  for j in range(4):
    qml.RY(np.pi *phi[j], wires = j)

  # random circuit

  RandomLayers(rand_params, wires = list(range(4)))


  # Measurement
  return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %% [markdown]
# ### The convolutional Scheme
#
#
#
# 1.   the image is divided into squares of $2 \times 2$ pixels
# 2.   each square is processed by the quantum circuit
# 3. the $4$ expectation values are mapped into $4$ different channels of a single output pixel

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# ### Quantum Preprocessing
#
# Since we are not going to train the quantum convolution layer, it is more efficient to apply it as a “pre-processing” layer to all the images of our dataset. Later an entirely classical model will be directly trained and tested on the pre-processed dataset, avoiding unnecessary repetitions of quantum computations.
#
# The pre-processed images will be saved in the folder SAVE_PATH. Once saved, they can be directly loaded by setting PREPROCESS = False, otherwise the quantum convolution is evaluated at each run of the code.

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save( "q_train_images.npy", q_train_images)
    np.save( "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load( "q_train_images.npy")
q_test_images = np.load( "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
#
# Quantum pre-processing of test images:

# %% [markdown]
# ### Visualize

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# Below each input image, the
# 4
#  output channels generated by the quantum convolution are visualized in gray scale.
#
# One can clearly notice the downsampling of the resolution and some local distortion introduced by the quantum kernel. On the other hand the global shape of the image is preserved, as expected for a convolution layer.

# %% [markdown]
# ### Hybrid quantum-classical model
# After the application of the quantum convolution layer we feed the resulting features into a classical neural network that will be trained to classify the
# 10
#  different digits of the MNIST dataset.
#
# We use a very simple model: just a fully connected layer with 10 output nodes with a final softmax activation function.
#
# The model is compiled with a stochastic-gradient-descent optimizer, and a cross-entropy loss function.

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ### Training
#
# We first initialize an instance of the model, then we train and validate it with the dataset that has been already pre-processed by a quantum convolution

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/40
# 125/125 - 1s - loss: 2.0057 - accuracy: 0.3720 - val_loss: 1.8340 - val_accuracy: 0.4300 - 787ms/epoch - 6ms/step
# Epoch 2/40
# 125/125 - 0s - loss: 1.3704 - accuracy: 0.6900 - val_loss: 1.4767 - val_accuracy: 0.5633 - 314ms/epoch - 3ms/step
# Epoch 3/40
# 125/125 - 0s - loss: 1.0435 - accuracy: 0.7820 - val_loss: 1.2928 - val_accuracy: 0.6367 - 349ms/epoch - 3ms/step
# Epoch 4/40
# 125/125 - 0s - loss: 0.8507 - accuracy: 0.8360 - val_loss: 1.1394 - val_accuracy: 0.6800 - 277ms/epoch - 2ms/step
# Epoch 5/40
# 125/125 - 0s - loss: 0.7055 - accuracy: 0.8720 - val_loss: 1.0622 - val_accuracy: 0.6833 - 279ms/epoch - 2ms/step
# Epoch 6/40
# 125/125 - 0s - loss: 0.6136 - accuracy: 0.8860 - val_loss: 0.9770 - val_accuracy: 0.7300 - 295ms/epoch - 2ms/step
# Epoch 7/40
# 125/125 - 0s - loss: 0.5422 - accuracy: 0.8980 - val_loss: 0.9225 - val_accuracy: 0.7367 - 335ms/epoch - 3ms/step
# Epoch 8/40
# 125/125 - 0s - loss: 0.4819 - accuracy: 0.9180 - val_loss: 0.8658 - val_accuracy: 0.7600 - 274ms/epoch - 2ms/step
# Epoch 9/40
# 125/125 - 0s - loss: 0.4342 - accuracy: 0.9300 - val_loss: 0.8339 - val_accuracy: 0.7600 - 352ms/epoch - 3ms/step
# Epoch 10/40
# 125/125 - 0s - loss: 0.3905 - accuracy: 0.9380 - val_loss: 0.8329 - val_accuracy: 0.7433 - 327ms/epoch - 3ms/step
# Epoch 11/40
# 125/125 - 0s - loss: 0.3677 - accuracy: 0.9300 - val_loss: 0.7734 - val_accuracy: 0.7667 - 265ms/epoch - 2ms/step
# Epoch 12/40
# 125/125 - 0s - loss: 0.3311 - accuracy: 0.9500 - val_loss: 0.7525 - val_accuracy: 0.7800 - 268ms/epoch - 2ms/step
# Epoch 13/40
# 125/125 - 0s - loss: 0.3025 - accuracy: 0.9500 - val_loss: 0.7416 - val_accuracy: 0.7900 - 276ms/epoch - 2ms/step
# Epoch 14/40
# 125/125 - 0s - loss: 0.2781 - accuracy: 0.9620 - val_loss: 0.7149 - val_accuracy: 0.7800 - 270ms/epoch - 2ms/step
# Epoch 15/40
# 125/125 - 0s - loss: 0.2591 - accuracy: 0.9620 - val_loss: 0.7085 - val_accuracy: 0.8100 - 271ms/epoch - 2ms/step
# Epoch 16/40
# 125/125 - 0s - loss: 0.2422 - accuracy: 0.9740 - val_loss: 0.7003 - val_accuracy: 0.7900 - 282ms/epoch - 2ms/step
# Epoch 17/40
# 125/125 - 0s - loss: 0.2238 - accuracy: 0.9660 - val_loss: 0.6680 - val_accuracy: 0.8033 - 278ms/epoch - 2ms/step
# Epoch 18/40
# 125/125 - 0s - loss: 0.2061 - accuracy: 0.9700 - val_loss: 0.6668 - val_accuracy: 0.7867 - 258ms/epoch - 2ms/step
# Epoch 19/40
# 125/125 - 0s - loss: 0.1910 - accuracy: 0.9780 - val_loss: 0.6497 - val_accuracy: 0.7900 - 324ms/epoch - 3ms/step
# Epoch 20/40
# 125/125 - 0s - loss: 0.1773 - accuracy: 0.9820 - val_loss: 0.6748 - val_accuracy: 0.8000 - 290ms/epoch - 2ms/step
# Epoch 21/40
# 125/125 - 0s - loss: 0.1700 - accuracy: 0.9820 - val_loss: 0.6480 - val_accuracy: 0.7967 - 271ms/epoch - 2ms/step
# Epoch 22/40
# 125/125 - 0s - loss: 0.1539 - accuracy: 0.9860 - val_loss: 0.6388 - val_accuracy: 0.7900 - 268ms/epoch - 2ms/step
# Epoch 23/40
# 125/125 - 0s - loss: 0.1478 - accuracy: 0.9920 - val_loss: 0.6299 - val_accuracy: 0.7933 - 332ms/epoch - 3ms/step
# Epoch 24/40
# 125/125 - 0s - loss: 0.1368 - accuracy: 0.9900 - val_loss: 0.6204 - val_accuracy: 0.8000 - 333ms/epoch - 3ms/step
# Epoch 25/40
# 125/125 - 0s - loss: 0.1247 - accuracy: 0.9920 - val_loss: 0.6307 - val_accuracy: 0.7800 - 272ms/epoch - 2ms/step
# Epoch 26/40
# 125/125 - 0s - loss: 0.1188 - accuracy: 0.9920 - val_loss: 0.6158 - val_accuracy: 0.7933 - 286ms/epoch - 2ms/step
# Epoch 27/40
# 125/125 - 0s - loss: 0.1114 - accuracy: 0.9920 - val_loss: 0.6226 - val_accuracy: 0.7833 - 259ms/epoch - 2ms/step
# Epoch 28/40
# 125/125 - 0s - loss: 0.1048 - accuracy: 0.9940 - val_loss: 0.6183 - val_accuracy: 0.7867 - 270ms/epoch - 2ms/step
# Epoch 29/40
# 125/125 - 0s - loss: 0.0979 - accuracy: 0.9960 - val_loss: 0.6230 - val_accuracy: 0.7800 - 318ms/epoch - 3ms/step
# Epoch 30/40
# 125/125 - 0s - loss: 0.0909 - accuracy: 0.9980 - val_loss: 0.6090 - val_accuracy: 0.8100 - 271ms/epoch - 2ms/step
# Epoch 31/40
# 125/125 - 0s - loss: 0.0850 - accuracy: 0.9940 - val_loss: 0.6261 - val_accuracy: 0.7767 - 262ms/epoch - 2ms/step
# Epoch 32/40
# 125/125 - 0s - loss: 0.0817 - accuracy: 0.9980 - val_loss: 0.6097 - val_accuracy: 0.7833 - 256ms/epoch - 2ms/step
# Epoch 33/40
# 125/125 - 0s - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.5997 - val_accuracy: 0.8100 - 330ms/epoch - 3ms/step
# Epoch 34/40
# 125/125 - 0s - loss: 0.0722 - accuracy: 1.0000 - val_loss: 0.6064 - val_accuracy: 0.7900 - 258ms/epoch - 2ms/step
# Epoch 35/40
# 125/125 - 0s - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.5917 - val_accuracy: 0.7967 - 270ms/epoch - 2ms/step
# Epoch 36/40
# 125/125 - 0s - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.5935 - val_accuracy: 0.8000 - 272ms/epoch - 2ms/step
# Epoch 37/40
# 125/125 - 0s - loss: 0.0603 - accuracy: 1.0000 - val_loss: 0.6468 - val_accuracy: 0.7800 - 287ms/epoch - 2ms/step
# Epoch 38/40
# 125/125 - 0s - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.5853 - val_accuracy: 0.8033 - 330ms/epoch - 3ms/step
# Epoch 39/40
# 125/125 - 0s - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.7767 - 264ms/epoch - 2ms/step
# Epoch 40/40
# 125/125 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.5833 - val_accuracy: 0.8000 - 323ms/epoch - 3ms/step

# %% [markdown]
# In order to compare the results achievable with and without the quantum convolution layer, we initialize also a “classical” instance of the model that will be directly trained and validated with the raw MNIST images (i.e., without quantum pre-processing).

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/40
# 125/125 - 1s - loss: 1.5645 - accuracy: 0.5840 - val_loss: 1.2415 - val_accuracy: 0.6800 - 810ms/epoch - 6ms/step
# Epoch 2/40
# 125/125 - 0s - loss: 0.7911 - accuracy: 0.8440 - val_loss: 0.9204 - val_accuracy: 0.7633 - 366ms/epoch - 3ms/step
# Epoch 3/40
# 125/125 - 0s - loss: 0.5590 - accuracy: 0.8820 - val_loss: 0.7720 - val_accuracy: 0.7833 - 263ms/epoch - 2ms/step
# Epoch 4/40
# 125/125 - 0s - loss: 0.4412 - accuracy: 0.9060 - val_loss: 0.6924 - val_accuracy: 0.8067 - 340ms/epoch - 3ms/step
# Epoch 5/40
# 125/125 - 0s - loss: 0.3664 - accuracy: 0.9240 - val_loss: 0.6339 - val_accuracy: 0.8333 - 289ms/epoch - 2ms/step
# Epoch 6/40
# 125/125 - 0s - loss: 0.3147 - accuracy: 0.9280 - val_loss: 0.5796 - val_accuracy: 0.8433 - 271ms/epoch - 2ms/step
# Epoch 7/40
# 125/125 - 0s - loss: 0.2736 - accuracy: 0.9440 - val_loss: 0.5548 - val_accuracy: 0.8500 - 362ms/epoch - 3ms/step
# Epoch 8/40
# 125/125 - 0s - loss: 0.2419 - accuracy: 0.9560 - val_loss: 0.5222 - val_accuracy: 0.8633 - 320ms/epoch - 3ms/step
# Epoch 9/40
# 125/125 - 0s - loss: 0.2130 - accuracy: 0.9560 - val_loss: 0.5119 - val_accuracy: 0.8467 - 258ms/epoch - 2ms/step
# Epoch 10/40
# 125/125 - 0s - loss: 0.1912 - accuracy: 0.9680 - val_loss: 0.4948 - val_accuracy: 0.8500 - 320ms/epoch - 3ms/step
# Epoch 11/40
# 125/125 - 0s - loss: 0.1734 - accuracy: 0.9780 - val_loss: 0.4774 - val_accuracy: 0.8600 - 258ms/epoch - 2ms/step
# Epoch 12/40
# 125/125 - 0s - loss: 0.1548 - accuracy: 0.9780 - val_loss: 0.4704 - val_accuracy: 0.8567 - 277ms/epoch - 2ms/step
# Epoch 13/40
# 125/125 - 0s - loss: 0.1399 - accuracy: 0.9820 - val_loss: 0.4617 - val_accuracy: 0.8667 - 261ms/epoch - 2ms/step
# Epoch 14/40
# 125/125 - 0s - loss: 0.1265 - accuracy: 0.9840 - val_loss: 0.4563 - val_accuracy: 0.8667 - 276ms/epoch - 2ms/step
# Epoch 15/40
# 125/125 - 0s - loss: 0.1155 - accuracy: 0.9880 - val_loss: 0.4468 - val_accuracy: 0.8633 - 257ms/epoch - 2ms/step
# Epoch 16/40
# 125/125 - 0s - loss: 0.1061 - accuracy: 0.9920 - val_loss: 0.4446 - val_accuracy: 0.8667 - 267ms/epoch - 2ms/step
# Epoch 17/40
# 125/125 - 0s - loss: 0.0966 - accuracy: 0.9960 - val_loss: 0.4321 - val_accuracy: 0.8667 - 339ms/epoch - 3ms/step
# Epoch 18/40
# 125/125 - 0s - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.4306 - val_accuracy: 0.8700 - 334ms/epoch - 3ms/step
# Epoch 19/40
# 125/125 - 0s - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.4226 - val_accuracy: 0.8667 - 334ms/epoch - 3ms/step
# Epoch 20/40
# 125/125 - 0s - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.4228 - val_accuracy: 0.8667 - 280ms/epoch - 2ms/step
# Epoch 21/40
# 125/125 - 0s - loss: 0.0683 - accuracy: 1.0000 - val_loss: 0.4223 - val_accuracy: 0.8667 - 334ms/epoch - 3ms/step
# Epoch 22/40
# 125/125 - 0s - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.8667 - 332ms/epoch - 3ms/step
# Epoch 23/40
# 125/125 - 0s - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.8667 - 276ms/epoch - 2ms/step
# Epoch 24/40
# 125/125 - 0s - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.4166 - val_accuracy: 0.8667 - 330ms/epoch - 3ms/step
# Epoch 25/40
# 125/125 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.4145 - val_accuracy: 0.8667 - 326ms/epoch - 3ms/step
# Epoch 26/40
# 125/125 - 0s - loss: 0.0472 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8667 - 322ms/epoch - 3ms/step
# Epoch 27/40
# 125/125 - 0s - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.8667 - 345ms/epoch - 3ms/step
# Epoch 28/40
# 125/125 - 0s - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8700 - 270ms/epoch - 2ms/step
# Epoch 29/40
# 125/125 - 0s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.4152 - val_accuracy: 0.8700 - 266ms/epoch - 2ms/step
# Epoch 30/40
# 125/125 - 0s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 0.8667 - 354ms/epoch - 3ms/step
# Epoch 31/40
# 125/125 - 0s - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8667 - 337ms/epoch - 3ms/step
# Epoch 32/40
# 125/125 - 0s - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.8700 - 328ms/epoch - 3ms/step
# Epoch 33/40
# 125/125 - 0s - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.4184 - val_accuracy: 0.8700 - 294ms/epoch - 2ms/step
# Epoch 34/40
# 125/125 - 0s - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.8667 - 328ms/epoch - 3ms/step
# Epoch 35/40
# 125/125 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.8667 - 327ms/epoch - 3ms/step
# Epoch 36/40
# 125/125 - 0s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.8700 - 264ms/epoch - 2ms/step
# Epoch 37/40
# 125/125 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.4117 - val_accuracy: 0.8733 - 287ms/epoch - 2ms/step
# Epoch 38/40
# 125/125 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.4101 - val_accuracy: 0.8733 - 253ms/epoch - 2ms/step
# Epoch 39/40
# 125/125 - 0s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.8700 - 326ms/epoch - 3ms/step
# Epoch 40/40
# 125/125 - 0s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4110 - val_accuracy: 0.8667 - 329ms/epoch - 3ms/step

# %% [markdown]
# ## Results

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
